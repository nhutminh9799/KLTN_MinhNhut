# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from pandas_datareader import data as pdr
from collections import deque
import random
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()

# %%
df_full = pd.read_csv('BTC.csv')
df_full.pop('Currency')
# Out:
# 0      BTC
# 1      BTC
# 2      BTC
# 3      BTC
# 4      BTC
#       ...
# 161    BTC
# 162    BTC
# 163    BTC
# 164    BTC
# 165    BTC
# Name: Currency, Length: 166, dtype: object

# %%
df_full
# Out:
#           Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0     1/1/2021          29111.52157     28872.82977     29280.04533
# 1     1/2/2021          29333.60512     28935.81098     29601.59490
# 2     1/3/2021          32154.16736     29353.64061     33064.67353
# 3     1/4/2021          33002.53643     32074.10661     34452.08034
# 4     1/5/2021          31431.61228     32788.58345     33358.39935
# ..         ...                  ...             ...             ...
# 161  6/11/2021          36715.04710     37403.60397     38461.25074
# 162  6/12/2021          37341.58943     36695.08131     37587.39855
# 163  6/13/2021          35655.16445     37339.00024     37459.96028
# 164  6/14/2021          38894.55627     35568.31876     39295.84866
# 165  6/15/2021          40162.32007     39016.52826     41046.76952
#
#      24h Low (USD)     Close
# 0      27916.62506  2.911152
# 1      28753.41231  2.933361
# 2      29012.92789  3.215417
# 3      31885.58162  3.300254
# 4      28154.11030  3.143161
# ..             ...       ...
# 161    35827.50618  3.671505
# 162    35982.33038  3.734159
# 163    34682.01043  3.565516
# 164    34822.58005  3.889456
# 165    38750.01315  4.016232
#
# [166 rows x 6 columns]

# %%
df= df_full.copy()
name = 'Q-Learning-Model'
class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        #-------------------------- 
        # Giai đoạn Định nghĩa
        #-------------------------- 
        #Kích cỡ của Size Q-Learning
        self.state_size = state_size
        #Kích cỡ Window
        self.window_size = window_size
        #Kích cỡ nữa Window
        self.half_window = window_size // 2
        #Giá trị mà ta quan tâm ở đây thường quan tâm đến Closing Price
        self.trend = trend
        #Bước nhảy
        self.skip = skip
        #Ví trong bài toán này chỉ có 3 hành động Buy/Sell/Hold --> action_size = 3
        self.action_size = 3
        self.batch_size = batch_size
        #Hàng đọi có chiều dài tối đa 1000 phần tử
        self.memory = deque(maxlen = 1000)
        self.inventory = []
        #Các hằng số của mô hình
        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        
        #-------------------------- 
        # Giai đoạn Deep Q-learning
        #-------------------------- 
        # 1. Pha chạy các thư viện tensorflow DQN
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        # 2. Input
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        # 3. Output
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        # 4. Khởi tạo layer với hàm activtion là relu
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        # 5. Hàm chi phí trong DQN
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        # 6. Tối ưu hàm chi phí
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        # 7. Đưa các biến trong phiên làm việc của tensorflow DQN lên toàn cục
        self.sess.run(tf.global_variables_initializer())
        #-------------------------- 
    
    #Hàm chọn hành động giai đoạn đầu có thể là giá trị ngẫu nhiên tới một khoảng thời gian nào đó sẽ lấy hàm argmax để học
    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    def replay(self, batch_size):
        #Khởi tạo mini_batch là []
        mini_batch = []
        #Xem chiều dài của memory
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        #Truyền State và Action
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    def train(self, iterations, checkpoint, initial_money):
        #self: chính là chính bản thân của class
        for i in range(iterations):
            #Tổng lợi nhuận ban đầu
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                #Hành động mua và bán
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                
                #Xem tiền đã bị giảm/tăng bao nhiêu phần sau mỗi lần giao dịch
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
              
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost, starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 10
skip = 1
batch_size = 10
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
iteration_size = len(df_full)//batch_size
iteration_size = iteration_size*10
agent.train(iterations = iteration_size, checkpoint = 10, initial_money = initial_money)
# Out:
# epoch: 10, total rewards: 22.242203.3, cost: 0.002031, total money: 9765.848389
# epoch: 20, total rewards: 21.676641.3, cost: 0.002234, total money: 9760.508234
# epoch: 30, total rewards: 22.494846.3, cost: 0.002203, total money: 9761.326439
# epoch: 40, total rewards: 22.494846.3, cost: 0.002150, total money: 9767.106086
# epoch: 50, total rewards: 20.411419.3, cost: 0.002232, total money: 9743.610521
# epoch: 60, total rewards: 23.785945.3, cost: 0.002073, total money: 9772.851975
# epoch: 70, total rewards: 23.652896.3, cost: 0.001965, total money: 9791.928119
# epoch: 80, total rewards: 21.379803.3, cost: 0.001973, total money: 9784.709699
# epoch: 90, total rewards: 22.677830.3, cost: 0.001985, total money: 9776.493950
# epoch: 100, total rewards: 22.677830.3, cost: 0.001962, total money: 9776.493950
# epoch: 110, total rewards: 22.127325.3, cost: 0.002007, total money: 9760.664242
# epoch: 120, total rewards: 23.861667.3, cost: 0.001892, total money: 9782.378306
# epoch: 130, total rewards: 23.549232.3, cost: 0.001823, total money: 9793.657581
# epoch: 140, total rewards: 22.494865.3, cost: 0.001712, total money: 9816.175685
# epoch: 150, total rewards: 23.600747.3, cost: 0.001786, total money: 9792.451623
# epoch: 160, total rewards: 24.800813.3, cost: 0.001797, total money: 9784.636722

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 5: buy 1 unit at price 3.443361, total balance 9996.556639
# day 6: buy 1 unit at price 3.627576, total balance 9992.929064
# day 7, sell 1 unit at price 3.971351, investment 15.333571 %, total balance 9996.900414,
# day 10: buy 1 unit at price 3.870977, total balance 9993.029438
# day 11: buy 1 unit at price 3.440964, total balance 9989.588474
# day 15, sell 1 unit at price 3.675158, investment 1.311699 %, total balance 9993.263632,
# day 16: buy 1 unit at price 3.601678, total balance 9989.661954
# day 17: buy 1 unit at price 3.637581, total balance 9986.024373
# day 18: buy 1 unit at price 3.634661, total balance 9982.389712
# day 21: buy 1 unit at price 3.060618, total balance 9979.329094
# day 22: buy 1 unit at price 3.336837, total balance 9975.992257
# day 25: buy 1 unit at price 3.250026, total balance 9972.742232
# day 27: buy 1 unit at price 3.053500, total balance 9969.688732
# day 28: buy 1 unit at price 3.340822, total balance 9966.347910
# day 29: buy 1 unit at price 3.484256, total balance 9962.863654
# day 30, sell 1 unit at price 3.462237, investment -10.559072 %, total balance 9966.325892,
# day 32: buy 1 unit at price 3.361332, total balance 9962.964559
# day 33: buy 1 unit at price 3.563290, total balance 9959.401269
# day 36: buy 1 unit at price 3.785160, total balance 9955.616110
# day 37: buy 1 unit at price 4.030280, total balance 9951.585830
# day 38: buy 1 unit at price 3.846168, total balance 9947.739661
# day 39: buy 1 unit at price 4.471669, total balance 9943.267993
# day 42: buy 1 unit at price 4.750090, total balance 9938.517903
# day 44: buy 1 unit at price 4.700519, total balance 9933.817384
# day 47: buy 1 unit at price 4.884041, total balance 9928.933343
# day 50: buy 1 unit at price 5.571920, total balance 9923.361422
# day 52: buy 1 unit at price 5.712864, total balance 9917.648558
# day 53: buy 1 unit at price 5.418191, total balance 9912.230367
# day 55: buy 1 unit at price 4.874543, total balance 9907.355823
# day 58: buy 1 unit at price 4.664261, total balance 9902.691563
# day 59: buy 1 unit at price 4.509281, total balance 9898.182282
# day 60, sell 1 unit at price 4.924891, investment 43.125329 %, total balance 9903.107173,
# day 61, sell 1 unit at price 4.790078, investment 32.995724 %, total balance 9907.897251,
# day 62: buy 1 unit at price 5.081186, total balance 9902.816066
# day 63: buy 1 unit at price 4.825949, total balance 9897.990117
# day 64: buy 1 unit at price 4.914973, total balance 9893.075144
# day 65: buy 1 unit at price 4.887915, total balance 9888.187229
# day 70, sell 1 unit at price 5.763676, investment 58.448034 %, total balance 9893.950904,
# day 71: buy 1 unit at price 5.730617, total balance 9888.220288
# day 72: buy 1 unit at price 6.074304, total balance 9882.145984
# day 80: buy 1 unit at price 5.779647, total balance 9876.366337
# day 81, sell 1 unit at price 5.432936, investment 49.475727 %, total balance 9881.799273,
# day 82: buy 1 unit at price 5.479430, total balance 9876.319843
# day 83: buy 1 unit at price 5.278775, total balance 9871.041068
# day 85, sell 1 unit at price 5.448305, investment 78.013202 %, total balance 9876.489373,
# day 86, sell 1 unit at price 5.623436, investment 68.525951 %, total balance 9882.112809,
# day 87, sell 1 unit at price 5.534393, investment 70.287661 %, total balance 9887.647201,
# day 88, sell 1 unit at price 5.762768, investment 88.726643 %, total balance 9893.409969,
# day 89: buy 1 unit at price 5.873448, total balance 9887.536521
# day 90: buy 1 unit at price 5.872466, total balance 9881.664055
# day 98: buy 1 unit at price 5.788091, total balance 9875.875964
# day 99: buy 1 unit at price 5.817191, total balance 9870.058774
# day 100, sell 1 unit at price 5.929595, investment 77.489112 %, total balance 9875.988369,
# day 102: buy 1 unit at price 5.985320, total balance 9870.003049
# day 103: buy 1 unit at price 6.322388, total balance 9863.680660
# day 104: buy 1 unit at price 6.292656, total balance 9857.388005
# day 106: buy 1 unit at price 6.196578, total balance 9851.191426
# day 111, sell 1 unit at price 5.414443, investment 55.397398 %, total balance 9856.605869,
# day 113: buy 1 unit at price 5.066914, total balance 9851.538955
# day 114, sell 1 unit at price 5.073377, investment 50.933524 %, total balance 9856.612332,
# day 115, sell 1 unit at price 4.854295, investment 36.230701 %, total balance 9861.466627,
# day 116: buy 1 unit at price 5.355871, total balance 9856.110756
# day 117: buy 1 unit at price 5.512386, total balance 9850.598370
# day 118, sell 1 unit at price 5.459152, investment 44.225132 %, total balance 9856.057521,
# day 119: buy 1 unit at price 5.326030, total balance 9850.731492
# day 120: buy 1 unit at price 5.730265, total balance 9845.001227
# day 121: buy 1 unit at price 5.767798, total balance 9839.233430
# day 124: buy 1 unit at price 5.365884, total balance 9833.867545
# day 128: buy 1 unit at price 5.878821, total balance 9827.988724
# day 130: buy 1 unit at price 5.571555, total balance 9822.417170
# day 131: buy 1 unit at price 5.657356, total balance 9816.759814
# day 137: buy 1 unit at price 4.314447, total balance 9812.445367
# day 138: buy 1 unit at price 4.319605, total balance 9808.125762
# day 139, sell 1 unit at price 3.943924, investment -2.142685 %, total balance 9812.069686,
# day 140: buy 1 unit at price 3.975609, total balance 9808.094077
# day 141: buy 1 unit at price 3.692177, total balance 9804.401900
# day 143: buy 1 unit at price 3.425955, total balance 9800.975946
# day 144: buy 1 unit at price 3.808579, total balance 9797.167367
# day 145: buy 1 unit at price 3.829045, total balance 9793.338322
# day 146, sell 1 unit at price 3.891500, investment 1.178637 %, total balance 9797.229822,
# day 147: buy 1 unit at price 3.871777, total balance 9793.358045
# day 148: buy 1 unit at price 3.489801, total balance 9789.868245
# day 149: buy 1 unit at price 3.453552, total balance 9786.414692
# day 150: buy 1 unit at price 3.574966, total balance 9782.839727
# day 152, sell 1 unit at price 3.641975, investment -18.554452 %, total balance 9786.481702,
# day 154: buy 1 unit at price 3.895849, total balance 9782.585852
# day 155: buy 1 unit at price 3.719010, total balance 9778.866842
# day 157: buy 1 unit at price 3.533568, total balance 9775.333274
# day 162, sell 1 unit at price 3.734159, investment -21.387613 %, total balance 9779.067433,

# %%
fig = plt.figure(figsize = (20,10))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()
